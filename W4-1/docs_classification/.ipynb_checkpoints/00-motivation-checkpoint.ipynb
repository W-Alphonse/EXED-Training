# %% [markdown]
# # Classification intro
#
# Author : Alexandre Gramfort

# %%
# %matplotlib inline
import math
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Example 1

# %%
mu1 = [2, 2]  # centre 1
mu2 = [-2, -3]  # cenrte 2
sigma1 = [[1, 0], [0, 1]]  # matrice de covariance de moyenne m1
sigma2 = [[1, 0], [0, 1]]

for mu, sigma, color in zip((mu1, mu2), (sigma1, sigma2), ('r', 'b')):
    X = np.random.multivariate_normal(mu, sigma, size=200)
    plt.scatter(X[:, 0], X[:, 1], color=color)
    plt.scatter(mu[0], mu[1], color='k', s=300., alpha=0.8, marker='h')

plt.axis('equal');

#Nearer centroid

# %% [markdown]
# ## Example 2

# %%
mu1 = [2, 2]
mu2 = [-6, -2]
sigma1 = [[7, 0], [0, 0.7]]
sigma2 = [[7, 0], [0, 0.7]]

for mu, sigma, color in zip((mu1, mu2), (sigma1, sigma2), ('r', 'b')):
    X = np.random.multivariate_normal(mu, sigma, size=200)
    plt.scatter(X[:, 0], X[:, 1], color=color)
    plt.scatter(mu[0], mu[1], color='k', s=300., alpha=0.8, marker='h')

plt.axis('equal');
# droite de separation: nearer centroid en oblique

# %% [markdown]
# ## Example 3

# %%
from sklearn import datasets

iris = datasets.load_iris()
X = iris.data
y = iris.target

# Take only 2 features
X = X[:, :2]

# And add a column of 1 for the intercept
X = np.concatenate((X, np.ones((X.shape[0], 1))), axis=1)

# Make it binary
X = X[y < 2]
y = y[y < 2]

y[y == 0] = -1

plt.scatter(X[y > 0, 0], X[y > 0, 1], color='r', label=iris.target_names[0])
plt.scatter(X[y < 0, 0], X[y < 0, 1], color='g', label=iris.target_names[1])
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
plt.legend();

# DEux classe correlé ds le me^me sens
